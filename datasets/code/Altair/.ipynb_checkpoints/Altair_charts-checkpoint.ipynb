# %%
import altair as alt

url = "https://raw.githubusercontent.com/opioiddatalab/drugchecking/main/datasets/code/Streamlit/x_strength.csv"

sensations = alt.Chart(url).mark_bar(size=40).encode(
    x=alt.X('sensations:N',
            sort=['weaker', 'normal', 'stronger'],
            axis=alt.Axis(title="Relative to Typical Current Supply")),
    y=alt.Y('samples:Q',
            axis=alt.Axis(title="Number of Samples")),
).properties(
    width=alt.Step(80),
    title="Sensations of Drugs Containing Xylazine"
).configure_axis(
   labelFontSize=13,
   titleFontSize=15,
   labelAngle=0
).configure_title(
   fontSize=16
)

# %% [markdown]
# Pie chart primary vs. trace

# %%
url = "https://raw.githubusercontent.com/opioiddatalab/drugchecking/main/datasets/code/Streamlit/x_strength.csv"

strength = alt.Chart(url).mark_bar(size=40).encode(
    x=alt.X('sensations:N',
            axis=alt.Axis(title="Relative to Typical Current Supply")),
    y=alt.Y('samples:Q',
            axis=alt.Axis(title="Number of Samples")),
).properties(
    width=alt.Step(80),
    title="Sensations of Drugs Containing Xylazine"
).configure_axis(
   labelFontSize=13,
   titleFontSize=15,
   labelAngle=0
).configure_title(
   fontSize=16
)

# %%
import pandas as pd
source = pd.DataFrame({"category": [1, 2, 3, 4, 5, 6], "value": [4, 6, 10, 3, 7, 8]})
source.head()
# Out:
#    category  value
# 0         1      4
# 1         2      6
# 2         3     10
# 3         4      3
# 4         5      7

# %%
alt.Chart(url).mark_arc().encode(
    theta=alt.Theta(field="value", type="quantitative"),
    color=alt.Color(field="category", type="nominal"),
)

# %%
import altair as alt
from vega_datasets import data

source = data.seattle_weather()
source.head()

# Size of the hexbins
size = 15
# Count of distinct x features
xFeaturesCount = 12
# Count of distinct y features
yFeaturesCount = 7
# Name of the x field
xField = 'date'
# Name of the y field
yField = 'date'


# the shape of a hexagon
hexagon = "M0,-2.3094010768L2,-1.1547005384 2,1.1547005384 0,2.3094010768 -2,1.1547005384 -2,-1.1547005384Z"

alt.Chart(source).mark_point(size=size**2, shape=hexagon).encode(
    x=alt.X('xFeaturePos:Q', axis=alt.Axis(title='Month',
                                           grid=False, tickOpacity=0, domainOpacity=0)),
    y=alt.Y('day(' + yField + '):O', axis=alt.Axis(title='Weekday',
                                                   labelPadding=20, tickOpacity=0, domainOpacity=0)),
    stroke=alt.value('black'),
    strokeWidth=alt.value(0.2),
    fill=alt.Color('mean(temp_max):Q', scale=alt.Scale(scheme='darkblue')),
    tooltip=['month(' + xField + '):O', 'day(' + yField + '):O', 'mean(temp_max):Q']
).transform_calculate(
    # This field is required for the hexagonal X-Offset
    xFeaturePos='(day(datum.' + yField + ') % 2) / 2 + month(datum.' + xField + ')'
).properties(
    # Exact scaling factors to make the hexbins fit
    width=size * xFeaturesCount * 2,
    height=size * yFeaturesCount * 1.7320508076,  # 1.7320508076 is approx. sin(60°)*2
).configure_view(
    strokeWidth=0
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
from vega_datasets import data

# Since the data is more than 5,000 rows we'll import it from a URL
source = data.seattle_temps.url
# https://github.com/altair-viz/vega_datasets/blob/master/vega_datasets/_data/seattle-temps.csv

alt.Chart(
    source,
    title="2010 Daily High Temperature (F) in Seattle, WA"
).mark_rect().encode(
    x='date(date):O',
    y='month(date):O',
    color=alt.Color('max(temp):Q', scale=alt.Scale(scheme="inferno")),
    tooltip=[
        alt.Tooltip('monthdate(date):T', title='Date'),
        alt.Tooltip('max(temp):Q', title='Max Temp')
    ]
).properties(width=550)
# Out:
# alt.Chart(...)

# %%
import altair as alt
import pandas as pd

# Since the data is more than 5,000 rows we'll import it from a URL
source = pd.read_csv("/Users/nabarun/Dropbox/Mac/Desktop/testdata.csv")

alt.Chart(
    source,
    title="Drug purity Metrics"
).mark_rect().encode(
    x=alt.Y('class:N', axis=alt.Axis(orient='top')),
    y=alt.Y('county:N'),
    color=alt.Color('num:Q', scale=alt.Scale(scheme="lightmulti")),
    tooltip=[
        alt.Tooltip('date:T', title='Latest'),
        alt.Tooltip('n:Q', title='Number of samples')
    ]       
).properties(
    width=200,
    title="Messy brew"
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
import pandas as pd

source = pd.DataFrame([
    {"x": 1,  "y": 28}, {"x": 2,  "y": 55},
    {"x": 3,  "y": 43}, {"x": 4,  "y": 91},
    {"x": 5,  "y": 81}, {"x": 6,  "y": 53},
    {"x": 7,  "y": 19}, {"x": 8,  "y": 87},
    {"x": 9,  "y": 52}, {"x": 10, "y": 48},
    {"x": 11, "y": 24}, {"x": 12, "y": 49},
    {"x": 13, "y": 87}, {"x": 14, "y": 66},
    {"x": 15, "y": 17}, {"x": 16, "y": 27},
    {"x": 17, "y": 68}, {"x": 18, "y": 16},
    {"x": 19, "y": 49}, {"x": 20, "y": 15}
])

area1 = alt.Chart(source).mark_area(
    clip=True,
    interpolate='monotone'
).encode(
    alt.X('x', scale=alt.Scale(zero=False, nice=False)),
    alt.Y('y', scale=alt.Scale(domain=[0, 50]), title='y'),
    opacity=alt.value(0.6)
).properties(
    width=500,
    height=75
)

area2 = area1.encode(
    alt.Y('ny:Q', scale=alt.Scale(domain=[0, 50]))
).transform_calculate(
    "ny", alt.datum.y - 50
)

area1 + area2
# Out:
# alt.LayerChart(...)

# %%
import altair as alt
import pandas as pd

source = pd.DataFrame([
    {"x": 1,  "y": 28}, {"x": 2,  "y": 55},
    {"x": 3,  "y": 43}, {"x": 4,  "y": 91},
    {"x": 5,  "y": 81}, {"x": 6,  "y": 53},
    {"x": 7,  "y": 19}, {"x": 8,  "y": 87},
    {"x": 9,  "y": 52}, {"x": 10, "y": 48},
    {"x": 11, "y": 24}, {"x": 12, "y": 49},
    {"x": 13, "y": 87}, {"x": 14, "y": 66},
    {"x": 15, "y": 17}, {"x": 16, "y": 27},
    {"x": 17, "y": 68}, {"x": 18, "y": 16},
    {"x": 19, "y": 49}, {"x": 20, "y": 15}
])

area1 = alt.Chart(source).mark_area(
    clip=True,
    interpolate='monotone'
).encode(
    alt.X('x', scale=alt.Scale(zero=False, nice=False)),
    alt.Y('y', scale=alt.Scale(domain=[0, 50]), title='y'),
    opacity=alt.value(0.6)
).properties(
    width=500,
    height=75
)

area2 = area1.encode(
    alt.Y('ny:Q', scale=alt.Scale(domain=[0, 50]))
).transform_calculate(
    "ny", alt.datum.y - 50
)

area1 + area2

# %%
import altair as at
import pandas as pd

source = pd.read_csv("/Users/nabarun/Dropbox/Mac/Documents/GitHub/PPPGHnaloxone/graphics/nlxdistributed.csv")
source.head()
# Out:
#    timepoint  nasal  im  tenml     agemed
# 0          8      0   0      1 -16.000000
# 1          9      0   0      6  19.333334
# 2         10      0   0      1 -24.000000
# 3         13      0   0      3 -23.000000
# 4         14      0   0      2        NaN

# %%
area1 = alt.Chart(source).mark_area(
    clip=True,
    interpolate='monotone'
).encode(
    alt.X('timepoint', scale=alt.Scale(zero=False, nice=False)),
    alt.Y('nasal', scale=alt.Scale(domain=[0, 101]), title='y'),
    opacity=alt.value(0.6)
).properties(
    width=500,
    height=75
)

area2 = area1.encode(
    alt.Y('ny:Q', scale=alt.Scale(domain=[0, 101]))
).transform_calculate(
    "ny", alt.datum.y - 50
)

area1 + area2
# Out:
# alt.LayerChart(...)

# %%
area1 = alt.Chart(source).mark_area(
    clip=True,
    interpolate='monotone'
).encode(
    alt.X('timepoint', scale=alt.Scale(zero=False, nice=False)),
    alt.Y('im', scale=alt.Scale(domain=[0,50]), title='y'),
    opacity=alt.value(0.6)
).properties(
    width=500,
    height=75
)

area2 = area1.encode(
    alt.Y('ny:Q', scale=alt.Scale(domain=[0,50]))
).transform_calculate(
    "ny", alt.datum.y - 50
)

area1 + area2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#     382
#     383         try:
# --> 384             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     385         except jsonschema.ValidationError:
#     386             dct = None
#
# /opt/anaconda3/lib/python3.9/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     324             result = _todict(self._args[0], validate=sub_validate, context=context)
#     325         elif not self._args:
# --> 326             result = _todict(
#     327                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     328                 validate=sub_validate,
#
# /opt/anaconda3/lib/python3.9/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
# ...

# %%
area1 = alt.Chart(source).mark_area(
    clip=True,
    interpolate='monotone'
).encode(
    alt.X('timepoint', scale=alt.Scale(zero=False, nice=False)),
    alt.Y('tenml', scale=alt.Scale(domain=[0, 50]), title='y'),
    opacity=alt.value(0.6)
).properties(
    width=500,
    height=75
)

area2 = area1.encode(
    alt.Y('ny:Q', scale=alt.Scale(domain=[0,50]))
).transform_calculate(
    "ny", alt.datum.y - 50
)

area1 + area2
# Out:
# alt.LayerChart(...)

# %%
area1 = alt.Chart(source).mark_area(
    clip=True,
    interpolate='monotone'
).encode(
    alt.X('timepoint', scale=alt.Scale(zero=False, nice=False)),
    alt.Y('agemed', scale=alt.Scale(domain=[-26, 26]), title='y'),
    opacity=alt.value(0.6)
).properties(
    width=500,
    height=75
)

area2 = area1.encode(
    alt.Y('ny:Q', scale=alt.Scale(domain=[-26,26]))
).transform_calculate(
    "ny", alt.datum.y - 50
)

area1 + area2
# Out:
# alt.LayerChart(...)

# %%
import altair as alt
import pandas as pd
source = pd.read_csv("/Users/nabarun/Dropbox/Mac/Documents/GitHub/PPPGHnaloxone/graphics/nlxdistributed.csv")
source.head()

alt.Chart(source).mark_area().encode(
    alt.X="year:Q",
    alt.Y="count:Q",
    color="formulation:N")
# Out:
#   File "/var/folders/pb/ckrlqwvj5852w41l9yr9hb3w0000gn/T/ipykernel_23518/3028589065.py", line 7
#     alt.X="year:Q",
#     ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
source.head(40)
# Out:
#          year          source  net_generation
# 0  2001-01-01    Fossil Fuels           35361
# 1  2002-01-01    Fossil Fuels           35991
# 2  2003-01-01    Fossil Fuels           36234
# 3  2004-01-01    Fossil Fuels           36205
# 4  2005-01-01    Fossil Fuels           36883
# 5  2006-01-01    Fossil Fuels           37014
# 6  2007-01-01    Fossil Fuels           41389
# 7  2008-01-01    Fossil Fuels           42734
# 8  2009-01-01    Fossil Fuels           38620
# 9  2010-01-01    Fossil Fuels           42750
# 10 2011-01-01    Fossil Fuels           39361
# 11 2012-01-01    Fossil Fuels           37379
# 12 2013-01-01    Fossil Fuels           34873
# 13 2014-01-01    Fossil Fuels           35250
# 14 2015-01-01    Fossil Fuels           32319
# 15 2016-01-01    Fossil Fuels           28437
# 16 2017-01-01    Fossil Fuels           29329
# 17 2001-01-01  Nuclear Energy            3853
# 18 2002-01-01  Nuclear Energy            4574
# ...

# %%
import altair as alt
from vega_datasets import data

source = data.iowa_electricity()

alt.Chart(source).mark_area().encode(
    x="year:T",
    y="net_generation:Q",
    color="source:N"
)
