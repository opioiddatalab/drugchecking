# %%
import json
import pandas as pd
import requests
headers = {
    "Authorization": "Bearer 6d9de38d-ab00-4fcc-9360-ec87952425cb",
    "User-Agent": "Get all samples",
	"Content-Type": "application/json",
}

response = requests.get("https://api.squarespace.com/1.0/commerce/products", headers=headers)
response.raise_for_status()
data = json.loads(response.content.decode(response.encoding))

# %%
pd.Series(data, name='name')
data.index.name = 'id'
s.reset_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/pb/ckrlqwvj5852w41l9yr9hb3w0000gn/T/ipykernel_17706/3269890398.py in <module>
#       1 pd.Series(data, name='name')
# ----> 2 data.index.name = 'id'
#       3 s.reset_index()
#
# AttributeError: 'dict' object has no attribute 'index'

# %%
print(type(data))
# Out:
# <class 'dict'>

# %% [raw]
# print (data['products']['name'][0])

# %%
data
# Out:
# {'products': [{'id': '62a3b952ca4edc65ed1ada50',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': '300298',
#    'description': "<p>From Winston-Salem, North Carolina on 5/18/2022<br>Assumed to be fentanyl<br><br><strong>This is a messy brew of 7 major substances:<ul><li>xylazine</li><li>mannitol</li><li>4-ANPP</li><li>fentanyl</li><li>heroin</li><li>non-specific sugars</li><li>p-fluorofentanyl</li></ul></strong><br>And we also found traces of dimethyl sulfone (methylsulfonylmethane MSM) + 6-monoacetylmorphine (6-MAM) + acetylcodeine. Trace substances in small quantities can sometimes be harmless, but other times can cause health problems. If you have unexpected sensations, it may be due to these.<br><br><strong>Fentanyl</strong> is potent and the amount changes by batch. If you weren't expecting it, consider getting test strips online or from a harm reduction program. <strong>Carry naloxone (Narcan)</strong> to reverse overdoses. <strong>Don't use alone</strong> so someone can help if you go out.<br><br><strong>Xylazine</strong> causes serious skin problems. These can happen anywhere on the body and don't heal quickly. And, <strong>xylazine</strong> can come on stronger than traditional dope and knock you out, so <strong>be mindful of your surroundings</strong>. It's best to avoid dope with xylazine. You might need medical attention to prevent long-term damage.<br><br>There are a lot of different substances in this sample. We don't know the harms that some of these can cause. Be careful and be prepared for unexpected reactions.<br><br><strong>Fluorofentanyl</strong> is showing up recently. It's the result of different raw materials being used to make fentanyl. We don't know yet if it causes any specific problems.<br><br>Looks = white powder, chunky<br><br>Need free supplies and advice to keep you safe? Find your nearest harm reduction program at harmreduction.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 6.9 = xylazine</li><li>Peak 7.3 = mannitol</li><li>Peak 8.39 = 4-ANPP</li><li>Peak 8.93 = heroin</li><li>Peak 9.1 = p-fluorofentanyl</li><li>Peak 9.24 = fentanyl</li></ul><br>Method(s): GCMS + Derivatized GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimportant. Contact us if you want details.<br><br><br> Lab Notes: <br>Record for Sample 300298 last updated 10 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/300298',
#    'urlSlug': 'p/300298',
#    'images': [{'id': '62a3b9552e46f11280289851',
#      'altText': '300298.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654896981103-VWI6I41ZAY02R9ZJSA7X/300298.PNG',
#      'originalSize': {'width': 1887, 'height': 418},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': 'c73ee9d5-c5c4-435a-be6b-7f40b2bc8acb',
#      'sku': 'SQ5165750',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-10T21:36:18.519Z',
#    'modifiedOn': '2022-06-17T13:00:18.715Z'},
#   {'id': '62ab16962bf64c78d1feaa4d',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': 'NC01312',
#    'description': "<p>From NHRC, North Carolina on  6/7/2022<br>Assumed to be fentanyl, heroin<br><br><strong>This is a messy brew of 8 major substances:<ul><li>phenethyl 4-ANPP</li><li>4-ANPP</li><li>benzoylecgonine (BZ)</li><li>methyl ecgonidine (MED)</li><li>tropacocaine</li><li>xylazine</li><li>fentanyl</li><li>cocaine</li></ul></strong><br><strong>Fentanyl</strong> is potent and the amount changes by batch. If you weren't expecting it, consider getting test strips online or from a harm reduction program. <strong>Carry naloxone (Narcan)</strong> to reverse overdoses. <strong>Don't use alone</strong> so someone can help if you go out.<br><br><strong>Xylazine</strong> causes serious skin problems. These can happen anywhere on the body and don't heal quickly. And, <strong>xylazine</strong> can come on stronger than traditional dope and knock you out, so <strong>be mindful of your surroundings</strong>. It's best to avoid dope with xylazine. You might need medical attention to prevent long-term damage.<br><br>There are a lot of different substances in this sample. We don't know the harms that some of these can cause. Be careful and be prepared for unexpected reactions.<br><br>Looks = tan<br><br>Need free supplies and advice to keep you safe? Find your nearest harm reduction program at harmreduction.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 11.6 = phenethyl 4-ANPP</li><li>Peak 4.52 = methyl ecgonidine (MED)</li><li>Peak 6.85 = tropacocaine</li><li>Peak 6.91 = xylazine</li><li>Peak 7.63 = cocaine</li><li>Peak 8.39 = 4-ANPP</li><li>Peak 8.79 = benzoylecgonine (BZ)</li><li>Peak 9.24 = fentanyl</li></ul><br>Method(s): GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimportant. Contact us if you want details.<br><br><br> Lab Notes: <br>Record for Sample NC01312 last updated 15 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/nc01312',
#    'urlSlug': 'p/nc01312',
#    'images': [{'id': '62ac7ab6243d1b4f83cce9e3',
#      'altText': '',
#      'orderIndex': -1,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1655470774730-S1E1JIZTBLX4NSWF102B/NC01312.PNG',
#      'originalSize': {'width': 1901, 'height': 423},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': '0166d5f3-60c8-477d-b0e7-cee695c31f62',
#      'sku': 'SQ8740455',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-16T11:40:06.081Z',
#    'modifiedOn': '2022-06-17T12:59:38.531Z'},
#   {'id': '62ab1699187fc259cb27a9fa',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': '300323',
#    'description': "<p>From NHRC, North Carolina on 6/13/2022<br>Assumed to be heroin<br><br><strong>2 major substances detected:<ul><li>xylazine</li><li>non-specific sugars</li></ul></strong><br>And we also found traces of cocaine + fentanyl + 4-ANPP. Trace substances in small quantities can sometimes be harmless, but other times can cause health problems. If you have unexpected sensations, it may be due to these.<br><br>There were just traces of <strong>fentanyl</strong>. This could have been contamination, like if drugs were stored in old bags. But since fentanyl is so potent you should be prepared. Consider getting <strong>fentanyl test strips</strong> online or from a harm reduction program if you weren't expecting it. <strong>Carry naloxone (Narcan)</strong> to reverse overdoses. Even traces of fentanyl could be a problem if you don't use opioids regularly. <strong>Don't use alone</strong> so someone can help if you go out.<br><br><strong>Xylazine</strong> causes serious skin problems. These can happen anywhere on the body and don't heal quickly. And, <strong>xylazine</strong> can come on stronger than traditional dope and knock you out, so <strong>be mindful of your surroundings</strong>. It's best to avoid dope with xylazine. You might need medical attention to prevent long-term damage.<br><br>Looks = powder<br><br>Need free supplies and advice to keep you safe? Find your nearest harm reduction program at harmreduction.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 6.89 = xylazine</li></ul><br>Method(s): GCMS + Derivatized GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimportant. Contact us if you want details.<br><br><br> Lab Notes: <br>Record for Sample 300323 last updated 15 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/300323',
#    'urlSlug': 'p/300323',
#    'images': [{'id': '62ac7aa667e88a36eb57841e',
#      'altText': '',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1655470758393-ZZC9F5ZN21TVMNSJ3Y13/300323.PNG',
#      'originalSize': {'width': 1887, 'height': 417},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': 'fd02641a-2288-42bf-9980-2d40cac81b5a',
#      'sku': 'SQ4431642',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-16T11:40:09.476Z',
#    'modifiedOn': '2022-06-17T12:59:22.036Z'},
#   {'id': '62ab169c2bf64c78d1feaa4e',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': '300360',
#    'description': "<p>From NHRC, North Carolina on 6/13/2022<br>Assumed to be heroin<br><br><strong>4 major substances detected:<ul><li>non-specific sugars</li><li>fentanyl</li><li>cocaine</li><li>N-phenylpropanamide</li></ul></strong><br>And we also found traces of 4-ANPP. Trace substances in small quantities can sometimes be harmless, but other times can cause health problems. If you have unexpected sensations, it may be due to these.<br><br><strong>Fentanyl</strong> is potent and the amount changes by batch. If you weren't expecting it, consider getting test strips online or from a harm reduction program. <strong>Carry naloxone (Narcan)</strong> to reverse overdoses. <strong>Don't use alone</strong> so someone can help if you go out.<br><br>There are a lot of different substances in this sample. We don't know the harms that some of these can cause. Be careful and be prepared for unexpected reactions.<br><br>Looks = powder<br><br>Need free supplies and advice to keep you safe? Find your nearest harm reduction program at harmreduction.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 5.03 = N-phenylpropanamide</li><li>Peak 7.62 = cocaine</li><li>Peak 9.24 = fentanyl</li></ul><br>Method(s): GCMS + Derivatized GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimportant. Contact us if you want details.<br><br><br> Lab Notes: <br>Record for Sample 300360 last updated 15 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/300360',
#    'urlSlug': 'p/300360',
#    'images': [{'id': '62ac7a918663dd4de9bd012c',
#      'altText': '',
#      'orderIndex': -1,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1655470737685-UWSLT7EEEMG6P3I5LGE8/300360.PNG',
#      'originalSize': {'width': 1889, 'height': 417},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': '19b27dfd-a415-4e87-9ea2-a543e0b8eba3',
#      'sku': 'SQ6168861',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-16T11:40:12.861Z',
#    'modifiedOn': '2022-06-17T12:59:02.492Z'},
#   {'id': '62a3b94f1b613f1cd1d46e64',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': '300297',
#    'description': "<p>From Winston-Salem, North Carolina on 5/10/2022<br>Assumed to be fentanyl<br><br><strong>5 major substances detected:<ul><li>xylazine</li><li>p-fluorofentanyl</li><li>non-specific sugars</li><li>acetaminophen</li><li>fentanyl</li></ul></strong><br>And we also found traces of dimethyl sulfone (methylsulfonylmethane MSM). Trace substances in small quantities can sometimes be harmless, but other times can cause health problems. If you have unexpected sensations, it may be due to these.<br><br><strong>Fentanyl</strong> is potent and the amount changes by batch. If you weren't expecting it, consider getting test strips online or from a harm reduction program. <strong>Carry naloxone (Narcan)</strong> to reverse overdoses. <strong>Don't use alone</strong> so someone can help if you go out.<br><br><strong>Xylazine</strong> causes serious skin problems. These can happen anywhere on the body and don't heal quickly. And, <strong>xylazine</strong> can come on stronger than traditional dope and knock you out, so <strong>be mindful of your surroundings</strong>. It's best to avoid dope with xylazine. You might need medical attention to prevent long-term damage.<br><br>There are a lot of different substances in this sample. We don't know the harms that some of these can cause. Be careful and be prepared for unexpected reactions.<br><br><strong>Fluorofentanyl</strong> is showing up recently. It's the result of different raw materials being used to make fentanyl. We don't know yet if it causes any specific problems.<br><br>Looks = white powder, chunky<br><br>Need free supplies and advice to keep you safe? Find your nearest harm reduction program at harmreduction.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 6.91 = xylazine</li><li>Peak 9.1 = p-fluorofentanyl</li><li>Peak 9.24 = fentanyl</li></ul><br>Method(s): GCMS + Derivatized GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimportant. Contact us if you want details.<br><br><br> Lab Notes: <br>Record for Sample 300297 last updated 10 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/300297',
#    'urlSlug': 'p/300297',
#    'images': [{'id': '62a3b9522e46f112802897de',
#      'altText': '300297.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654896978247-1XPQZYPY2XQI3GZBVQRK/300297.PNG',
#      'originalSize': {'width': 1879, 'height': 420},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': 'b8596090-9d20-4ef9-89fc-5e8c151197e7',
#      'sku': 'SQ6022662',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-10T21:36:15.352Z',
#    'modifiedOn': '2022-06-10T21:36:18.015Z'},
#   {'id': '62a3b94c8e490654c8c0e68f',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': '300290',
#    'description': "<p>From Greensboro, North Carolina on 5/20/2022<br>Assumed to be methamphetamine<br><br><strong>Only 1 major substance detected:<ul><li>methamphetamine</li></ul></strong><br>Looks = clear, white crystals, powder, shiny<br><br>The Xchange in Greensboro can help provide you with free supplies and advice to stay safe. 'If you want to improve your life we are here to help you. One goal at a time. You make the goals... we listen to you.'<br>1114 Grove Street, Greensboro, NC 27403<br>Phone: 336-669-5543<br>Open: Mon 1-7pm, Tue 1-7pm, Thu 1-5pm, Fri 1-8pm<br>ncurbansurvivorunion.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 3.32 = methamphetamine</li></ul><br>Method(s): GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimportant. Contact us if you want details.<br><br><br> Lab Notes: <br>Record for Sample 300290 last updated 10 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/300290',
#    'urlSlug': 'p/300290',
#    'images': [{'id': '62a3b94e2e46f11280289764',
#      'altText': '300290.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654896975055-BJCQMZL69R6OB1VBSBFU/300290.PNG',
#      'originalSize': {'width': 1883, 'height': 421},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': '68f860cb-2867-4c1e-a706-44fe40773bc1',
#      'sku': 'SQ8857048',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-10T21:36:12.477Z',
#    'modifiedOn': '2022-06-10T21:36:14.680Z'},
#   {'id': '62a3b9498e490654c8c0e688',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': '300280',
#    'description': "<p>From Greensboro, North Carolina on 5/20/2022<br>Assumed to be MDMA<br><br><strong>Only 1 major substance detected:<ul><li>caffeine</li></ul></strong><br>And we also found traces of methamphetamine + eutylone. Trace substances in small quantities can sometimes be harmless, but other times can cause health problems. If you have unexpected sensations, it may be due to these.<br><br>Looks = blue pill<br><br>The Xchange in Greensboro can help provide you with free supplies and advice to stay safe. 'If you want to improve your life we are here to help you. One goal at a time. You make the goals... we listen to you.'<br>1114 Grove Street, Greensboro, NC 27403<br>Phone: 336-669-5543<br>Open: Mon 1-7pm, Tue 1-7pm, Thu 1-5pm, Fri 1-8pm<br>ncurbansurvivorunion.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 6.39 = caffeine</li></ul><br>Method(s): GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimportant. Contact us if you want details.<br><br><br> Lab Notes: <br>Record for Sample 300280 last updated 10 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/300280',
#    'urlSlug': 'p/300280',
#    'images': [{'id': '62a3b94c2e46f11280289735',
#      'altText': '300280.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654896972197-J26S902U8YL6I3QKXY00/300280.PNG',
#      'originalSize': {'width': 1892, 'height': 420},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': '57e49191-2e6d-48b9-8a95-7f5c6569eba5',
#      'sku': 'SQ6888587',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-10T21:36:09.173Z',
#    'modifiedOn': '2022-06-10T21:36:11.889Z'},
#   {'id': '62a3b946187fc259cb254c93',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': '300276',
#    'description': "<p>From Greensboro, North Carolina on 5/20/2022<br>Assumed to be methamphetamine<br><br><strong>Only 1 major substance detected:<ul><li>methamphetamine</li></ul></strong><br>Looks = white crystals, powder, shiny<br><br>The Xchange in Greensboro can help provide you with free supplies and advice to stay safe. 'If you want to improve your life we are here to help you. One goal at a time. You make the goals... we listen to you.'<br>1114 Grove Street, Greensboro, NC 27403<br>Phone: 336-669-5543<br>Open: Mon 1-7pm, Tue 1-7pm, Thu 1-5pm, Fri 1-8pm<br>ncurbansurvivorunion.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 3.32 = methamphetamine</li></ul><br>Method(s): GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimportant. Contact us if you want details.<br><br><br> Lab Notes: <br>Record for Sample 300276 last updated 10 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/300276',
#    'urlSlug': 'p/300276',
#    'images': [{'id': '62a3b9482e46f112802896a9',
#      'altText': '300276.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654896968832-FBI27VS029UK2RAM4WDY/300276.PNG',
#      'originalSize': {'width': 1880, 'height': 424},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': 'db0fc3d2-4018-47db-af64-5b5686f04513',
#      'sku': 'SQ1534486',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-10T21:36:05.926Z',
#    'modifiedOn': '2022-06-10T21:36:08.312Z'},
#   {'id': '62a3b9421b613f1cd1d46e5f',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': '300274',
#    'description': "<p>From Winston-Salem, North Carolina on 5/10/2022<br>Assumed to be fentanyl, xylazine<br><br><strong>4 major substances detected:<ul><li>fentanyl</li><li>non-specific sugars</li><li>xylazine</li><li>p-fluorofentanyl</li></ul></strong><br>And we also found traces of 4-ANPP. Trace substances in small quantities can sometimes be harmless, but other times can cause health problems. If you have unexpected sensations, it may be due to these.<br><br><strong>Fentanyl</strong> is potent and the amount changes by batch. If you weren't expecting it, consider getting test strips online or from a harm reduction program. <strong>Carry naloxone (Narcan)</strong> to reverse overdoses. <strong>Don't use alone</strong> so someone can help if you go out.<br><br><strong>Xylazine</strong> causes serious skin problems. These can happen anywhere on the body and don't heal quickly. And, <strong>xylazine</strong> can come on stronger than traditional dope and knock you out, so <strong>be mindful of your surroundings</strong>. It's best to avoid dope with xylazine. You might need medical attention to prevent long-term damage.<br><br>There are a lot of different substances in this sample. We don't know the harms that some of these can cause. Be careful and be prepared for unexpected reactions.<br><br><strong>Fluorofentanyl</strong> is showing up recently. It's the result of different raw materials being used to make fentanyl. We don't know yet if it causes any specific problems.<br><br>Looks = white powder, shiny<br><br>Need free supplies and advice to keep you safe? Find your nearest harm reduction program at harmreduction.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 2.9 = xylazine</li><li>Peak 9.1 = p-fluorofentanyl</li><li>Peak 9.25 = fentanyl</li></ul><br>Method(s): GCMS + Derivatized GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimportant. Contact us if you want details.<br><br><br> Lab Notes: <br>Record for Sample 300274 last updated 10 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/300274',
#    'urlSlug': 'p/300274',
#    'images': [{'id': '62a3b9452e46f1128028966f',
#      'altText': '300274.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654896965576-FUP3Y4KMYDDB1UDWJOMI/300274.PNG',
#      'originalSize': {'width': 1873, 'height': 423},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': 'ee01400b-517f-467a-9c8c-854a7f55d06e',
#      'sku': 'SQ2727681',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-10T21:36:02.860Z',
#    'modifiedOn': '2022-06-10T21:36:05.347Z'},
#   {'id': '62a3b93f187fc259cb254c8c',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': '300264',
#    'description': "<p>From Greensboro, North Carolina on 5/20/2022<br>Assumed to be MDMA<br><br><strong>Only 1 major substance detected:<ul><li>3,4-MDMA</li></ul></strong><br>Looks = tan powder, chunky, shiny, flaky<br><br>The Xchange in Greensboro can help provide you with free supplies and advice to stay safe. 'If you want to improve your life we are here to help you. One goal at a time. You make the goals... we listen to you.'<br>1114 Grove Street, Greensboro, NC 27403<br>Phone: 336-669-5543<br>Open: Mon 1-7pm, Tue 1-7pm, Thu 1-5pm, Fri 1-8pm<br>ncurbansurvivorunion.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 5.13 = 3,4-MDMA</li></ul><br>Method(s): GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimportant. Contact us if you want details.<br><br><br> Lab Notes: <br>Record for Sample 300264 last updated 10 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/300264',
#    'urlSlug': 'p/300264',
#    'images': [{'id': '62a3b9412e46f112802895e8',
#      'altText': '300264.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654896962025-25WPS7WBQ9EO4Z2ENUE4/300264.PNG',
#      'originalSize': {'width': 1891, 'height': 421},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': 'ded34f40-77f2-4317-8bc3-b2e50d9e0603',
#      'sku': 'SQ4180044',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-10T21:35:59.309Z',
#    'modifiedOn': '2022-06-10T21:36:01.637Z'},
#   {'id': '62a3b93b1b613f1cd1d46e59',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': '300263',
#    'description': "<p>From Greensboro, North Carolina on 5/20/2022<br>Assumed to be heroin, fentanyl<br><br><strong>Only 1 major substance detected:<ul><li>methamphetamine</li></ul></strong><br>And we also found traces of cocaine. Trace substances in small quantities can sometimes be harmless, but other times can cause health problems. If you have unexpected sensations, it may be due to these.<br><br>Looks = gray-white, black specks powder, chunky<br><br>The Xchange in Greensboro can help provide you with free supplies and advice to stay safe. 'If you want to improve your life we are here to help you. One goal at a time. You make the goals... we listen to you.'<br>1114 Grove Street, Greensboro, NC 27403<br>Phone: 336-669-5543<br>Open: Mon 1-7pm, Tue 1-7pm, Thu 1-5pm, Fri 1-8pm<br>ncurbansurvivorunion.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 3.33 = methamphetamine</li></ul><br>Method(s): GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimportant. Contact us if you want details.<br><br><br> Lab Notes: <br>Record for Sample 300263 last updated 10 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/300263',
#    'urlSlug': 'p/300263',
#    'images': [{'id': '62a3b93e2e46f11280289535',
#      'altText': '300263.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654896959022-YS6ULQYE5VN1COZM3LHB/300263.PNG',
#      'originalSize': {'width': 1878, 'height': 418},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': '079e19d7-07a9-4474-bfc6-be42f11f524e',
#      'sku': 'SQ5238620',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-10T21:35:55.465Z',
#    'modifiedOn': '2022-06-10T21:35:58.755Z'},
#   {'id': '62a3b9388e490654c8c0e67d',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': '300258',
#    'description': "<p>From Winston-Salem, North Carolina on 5/19/2022<br>Assumed to be fentanyl<br><br><strong>4 major substances detected:<ul><li>fentanyl</li><li>dimethyl sulfone (methylsulfonylmethane MSM)</li><li>xylazine</li><li>p-fluorofentanyl</li></ul></strong><br>And we also found traces of 4-ANPP + N-phenylpropanamide. Trace substances in small quantities can sometimes be harmless, but other times can cause health problems. If you have unexpected sensations, it may be due to these.<br><br><strong>Fentanyl</strong> is potent and the amount changes by batch. If you weren't expecting it, consider getting test strips online or from a harm reduction program. <strong>Carry naloxone (Narcan)</strong> to reverse overdoses. <strong>Don't use alone</strong> so someone can help if you go out.<br><br><strong>Xylazine</strong> causes serious skin problems. These can happen anywhere on the body and don't heal quickly. And, <strong>xylazine</strong> can come on stronger than traditional dope and knock you out, so <strong>be mindful of your surroundings</strong>. It's best to avoid dope with xylazine. You might need medical attention to prevent long-term damage.<br><br>There are a lot of different substances in this sample. We don't know the harms that some of these can cause. Be careful and be prepared for unexpected reactions.<br><br><strong>Fluorofentanyl</strong> is showing up recently. It's the result of different raw materials being used to make fentanyl. We don't know yet if it causes any specific problems.<br><br>Looks = white powder, chunky<br><br>Need free supplies and advice to keep you safe? Find your nearest harm reduction program at harmreduction.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 2.33 = dimethyl sulfone (methylsulfonylmethane MSM)</li><li>Peak 6.9 = xylazine</li><li>Peak 9.1 = p-fluorofentanyl</li><li>Peak 9.26 = fentanyl</li></ul><br>Method(s): GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimportant. Contact us if you want details.<br><br><br> Lab Notes: <br>Record for Sample 300258 last updated 10 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/300258',
#    'urlSlug': 'p/300258',
#    'images': [{'id': '62a3b93a2e46f112802894d4',
#      'altText': '300258.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654896955090-8RT7KSEJMY73S84CS4E8/300258.PNG',
#      'originalSize': {'width': 1875, 'height': 426},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': '60431aa7-94ba-49b4-9b8e-881b0b766863',
#      'sku': 'SQ6755881',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-10T21:35:52.170Z',
#    'modifiedOn': '2022-06-10T21:35:54.718Z'},
#   {'id': '629a5920ca4edc65ed179343',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': 'NC01330',
#    'description': "<p>From Gastonia, North Carolina on  5/1/2022<br>Assumed to be heroin, fentanyl<br><br><strong>2 major substances detected:<ul><li>fentanyl</li><li>non-specific sugars</li></ul></strong><br>And we also found traces of 6-monoacetylmorphine (6-MAM) + 4-ANPP + acetyl fentanyl. Trace substances in small quantities can sometimes be harmless, but other times can cause health problems. If you have unexpected sensations, it may be due to these.<br><br><strong>Fentanyl</strong> is potent and the amount changes by batch. If you weren't expecting it, consider getting test strips online or from a harm reduction program. <strong>Carry naloxone (Narcan)</strong> to reverse overdoses. <strong>Don't use alone</strong> so someone can help if you go out.<br><br>Looks = clear, white powder<br><br>Need free supplies and advice to keep you safe? Find your nearest harm reduction program at harmreduction.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 9.25 = fentanyl</li></ul><br>Method(s): GCMS + Derivatized GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimportant. Contact us if you want details.<br><br>Record for Sample NC01330 last updated  3 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/nc01330',
#    'urlSlug': 'p/nc01330',
#    'images': [{'id': '629a59229086420e9bda3794',
#      'altText': 'NC01330.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654282530928-5BMQQ4NG4ZCXNGZJDGJZ/NC01330.PNG',
#      'originalSize': {'width': 1886, 'height': 425},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': 'dc13cf65-a6ed-488f-937a-bd0eda48834e',
#      'sku': 'SQ1565077',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-03T18:55:28.236Z',
#    'modifiedOn': '2022-06-03T18:57:28.860Z'},
#   {'id': '62977868ea75837f26c84953',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': '200521',
#    'description': "<p>From Greensboro, North Carolina on 9/21/2021<br>Assumed to be heroin, fentanyl<br><br><strong>Pretty sample with only 1 major substance detected:<ul><li>vitamin E acetate</li></ul></strong><br>And we also found traces of cocaine. Trace substances in small quantities can sometimes be harmless, but other times can cause health problems. If you have unexpected sensations, it may be due to these.<br><br>Looks = soft powder<br><br>The Xchange in Greensboro can help provide you with free supplies and advice to stay safe. 'If you want to improve your life we are here to help you. One goal at a time. You make the goals... we listen to you.'<br>1114 Grove Street, Greensboro, NC 27403<br>Phone: 336-669-5543<br>Open: Mon 1-7pm, Tue 1-7pm, Thu 1-5pm, Fri 1-8pm<br>ncurbansurvivorunion.org<br><br><br>Method(s): GCMS<br>Record for Sample 200521 last updated  1 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/200521',
#    'urlSlug': 'p/200521',
#    'images': [],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': '62644a09-60f8-4cb3-9ea1-42b82199fd1a',
#      'sku': 'SQ5838580',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-01T14:32:07.847Z',
#    'modifiedOn': '2022-06-03T18:45:38.954Z'},
#   {'id': '629777e9165fee684efeb9b7',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': 'USU207',
#    'description': "<p>From North Carolina<br>Unclear what it was before the lab<br><br><strong>2 major substances detected:<ul><li>heroin</li><li>cocaine</li></ul></strong><br>But we found lots of contaminants too, with traces of fentanyl + norcocaine + dimethyl sulfone (methylsulfonylmethane MSM) + levamisole + acetylcodeine + 6-monoacetylmorphine (6-MAM) + tropacocaine + methyl ecgonidine (MED). Trace substances in small quantities can sometimes be harmless, but other times can cause health problems. If you have unexpected sensations, it may be due to these.<br><br>There were just traces of <strong>fentanyl</strong>. This could have been contamination, like if drugs were stored in old bags. But since fentanyl is so potent you should be prepared. Consider getting <strong>fentanyl test strips</strong> online or from a harm reduction program if you weren't expecting it. <strong>Carry naloxone (Narcan)</strong> to reverse overdoses. Even traces of fentanyl could be a problem if you don't use opioids regularly. <strong>Don't use alone</strong> so someone can help if you go out.<br><br>Looks = powder<br><br>Need free supplies and advice to keep you safe? Find your nearest harm reduction program at harmreduction.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 16.68 = cocaine</li><li>Peak 19.14 = heroin</li></ul><br>Method(s): GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimporant. Contact us if you want details.<br><br>Record for Sample USU207 last updated  1 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/usu207',
#    'urlSlug': 'p/usu207',
#    'images': [{'id': '629777eba3024465ca0ebb86',
#      'altText': 'USU207.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654093803513-4Z6S50W6LGYKVGWJ93Q3/USU207.PNG',
#      'originalSize': {'width': 1888, 'height': 447},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': '59bb64a7-4952-4ab1-9d55-b2bc849d1691',
#      'sku': 'SQ1062644',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-01T14:30:01.452Z',
#    'modifiedOn': '2022-06-03T18:45:38.954Z'},
#   {'id': '6297785a6145924311fe759c',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': 'NC01029',
#    'description': "<p>From Greensboro, North Carolina on 7/29/2021<br>Assumed to be cocaine<br><br><strong>2 major substances detected:<ul><li>cocaine</li><li>methyl ecgonidine (MED)</li></ul></strong><br>But we found lots of contaminants too, with traces of norcocaine + ecgonine methylester (EME) + benzoylecgonine (BZ) + tropacocaine. Trace substances in small quantities can sometimes be harmless, but other times can cause health problems. If you have unexpected sensations, it may be due to these.<br><br>Looks = white flaky<br><br>The Xchange in Greensboro can help provide you with free supplies and advice to stay safe. 'If you want to improve your life we are here to help you. One goal at a time. You make the goals... we listen to you.'<br>1114 Grove Street, Greensboro, NC 27403<br>Phone: 336-669-5543<br>Open: Mon 1-7pm, Tue 1-7pm, Thu 1-5pm, Fri 1-8pm<br>ncurbansurvivorunion.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 4.53 = methyl ecgonidine (MED)</li><li>Peak 7.67 = cocaine</li></ul><br>Method(s): GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimporant. Contact us if you want details.<br><br>Record for Sample NC01029 last updated  1 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/nc01029',
#    'urlSlug': 'p/nc01029',
#    'images': [{'id': '6297785ca3024465ca0eca02',
#      'altText': 'NC01029.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654093916143-V0BZE8TRZEAQF3BYNHXV/NC01029.PNG',
#      'originalSize': {'width': 1893, 'height': 444},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': '1557fbc8-2bc1-49a4-ae74-69eb66ff2033',
#      'sku': 'SQ7611610',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-01T14:31:54.516Z',
#    'modifiedOn': '2022-06-03T18:45:38.954Z'},
#   {'id': '62977878ea75837f26c84960',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': '200316',
#    'description': "<p>From Boone, North Carolina on 12/17/2021<br>Assumed to be Ecstacy<br><br><strong>Pretty sample with only 1 major substance detected:<ul><li>3,4-MDMA</li></ul></strong><br>Looks = yellow powder<br><br>Need free supplies and advice to keep you safe? Find your nearest harm reduction program at harmreduction.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 5.37 = 3,4-MDMA</li></ul><br>Method(s): GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimporant. Contact us if you want details.<br><br>Record for Sample 200316 last updated  1 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/200316',
#    'urlSlug': 'p/200316',
#    'images': [{'id': '6297787aa3024465ca0ecdf9',
#      'altText': '200316.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654093946240-OQOELR7MYZJ87LFMXF7I/200316.PNG',
#      'originalSize': {'width': 1897, 'height': 439},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': '4fa31175-6ab7-4384-bd60-ea6829355638',
#      'sku': 'SQ3633025',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-01T14:32:24.738Z',
#    'modifiedOn': '2022-06-03T18:45:38.954Z'},
#   {'id': '629777ef165fee684efeb9ba',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': 'Heroin051721-1',
# ...
#    'urlSlug': 'p/200913',
#    'images': [],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': '572b4a13-ceea-4acb-a773-abf39e9e537f',
#      'sku': 'SQ6584383',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-01T14:32:28.995Z',
#    'modifiedOn': '2022-06-03T18:45:38.954Z'},
#   {'id': '629778156145924311fe7573',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': '300113',
#    'description': "<p>From Greensboro, North Carolina on 3/22/2022<br>Assumed to be heroin<br><br><strong>Sorry, no substances of interest detected.</strong><br>Looks = light tan powder<br><br>The Xchange in Greensboro can help provide you with free supplies and advice to stay safe. 'If you want to improve your life we are here to help you. One goal at a time. You make the goals... we listen to you.'<br>1114 Grove Street, Greensboro, NC 27403<br>Phone: 336-669-5543<br>Open: Mon 1-7pm, Tue 1-7pm, Thu 1-5pm, Fri 1-8pm<br>ncurbansurvivorunion.org<br><br><br>Method(s): GCMS<br>Record for Sample 300113 last updated  1 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/300113',
#    'urlSlug': 'p/300113',
#    'images': [],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': 'db6febbb-aa46-466c-ad20-e9476ac87ac7',
#      'sku': 'SQ3471028',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-01T14:30:45.434Z',
#    'modifiedOn': '2022-06-03T18:45:38.954Z'},
#   {'id': '629777ed165fee684efeb9b9',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': 'NC01380',
#    'description': "<p>From Greensboro, North Carolina on 12/21/2021<br>Assumed to be ketamine<br><br><strong>2 major substances detected:<ul><li>1-[(2-chlorophenyl)(methylimino)methyl]cyclopentanol</li><li>ketamine</li></ul></strong><br>There are a lot of different substances in this sample. We don't know the harms that some of these can cause. Be careful and be prepared for unexpected reactions.<br><br>Looks = white powder<br><br>The Xchange in Greensboro can help provide you with free supplies and advice to stay safe. 'If you want to improve your life we are here to help you. One goal at a time. You make the goals... we listen to you.'<br>1114 Grove Street, Greensboro, NC 27403<br>Phone: 336-669-5543<br>Open: Mon 1-7pm, Tue 1-7pm, Thu 1-5pm, Fri 1-8pm<br>ncurbansurvivorunion.org<br><br><br>Method(s): GCMS<br>Record for Sample NC01380 last updated  1 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/nc01380',
#    'urlSlug': 'p/nc01380',
#    'images': [],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': '921c6944-fdc5-48f3-bdbe-9dba35331322',
#      'sku': 'SQ4500560',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-01T14:30:05.724Z',
#    'modifiedOn': '2022-06-03T18:45:38.954Z'},
#   {'id': '629778666145924311fe75a5',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': '300119',
#    'description': "<p>From Greensboro, North Carolina on 3/17/2022<br>Assumed to be heroin<br><br><strong>2 major substances detected:<ul><li>fentanyl</li><li>4-ANPP</li></ul></strong><br>And we also found traces of tramadol + dimethyl sulfone (methylsulfonylmethane MSM) + phenethyl 4-ANPP. Trace substances in small quantities can sometimes be harmless, but other times can cause health problems. If you have unexpected sensations, it may be due to these.<br><br><strong>Fentanyl</strong> is potent and the amount changes by batch. If you weren't expecting it, consider getting test strips online or from a harm reduction program. <strong>Carry naloxone (Narcan)</strong> to reverse overdoses. <strong>Don't use alone</strong> so someone can help if you go out.<br><br>Looks = light tan, brown chunky, sticky, powder<br><br>The Xchange in Greensboro can help provide you with free supplies and advice to stay safe. 'If you want to improve your life we are here to help you. One goal at a time. You make the goals... we listen to you.'<br>1114 Grove Street, Greensboro, NC 27403<br>Phone: 336-669-5543<br>Open: Mon 1-7pm, Tue 1-7pm, Thu 1-5pm, Fri 1-8pm<br>ncurbansurvivorunion.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 8.41 = 4-ANPP</li><li>Peak 9.28 = fentanyl</li></ul><br>Method(s): GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimporant. Contact us if you want details.<br><br>Record for Sample 300119 last updated  1 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/300119',
#    'urlSlug': 'p/300119',
#    'images': [{'id': '62977867a3024465ca0ecb87',
#      'altText': '300119.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654093927532-J0AQOG8IM6D87ONSMOEX/300119.PNG',
#      'originalSize': {'width': 1891, 'height': 436},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': '05ad6293-0fc9-46c8-b143-cc79b337961a',
#      'sku': 'SQ4788848',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-01T14:32:05.987Z',
#    'modifiedOn': '2022-06-03T18:45:38.954Z'},
#   {'id': '6297788b165fee684efeba0b',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': 'NC01052',
#    'description': "<p>From Greensboro, North Carolina on 7/13/2021<br>Assumed to be heroin, cocaine<br><br><strong>3 major substances detected:<ul><li>cocaine</li><li>heroin</li><li>fentanyl</li></ul></strong><br>But we found lots of contaminants too, with traces of 6-monoacetylmorphine (6-MAM) + benzoylecgonine (BZ) + methyl ecgonidine (MED) + 4-ANPP + acetylcodeine. Trace substances in small quantities can sometimes be harmless, but other times can cause health problems. If you have unexpected sensations, it may be due to these.<br><br><strong>Fentanyl</strong> is potent and the amount changes by batch. If you weren't expecting it, consider getting test strips online or from a harm reduction program. <strong>Carry naloxone (Narcan)</strong> to reverse overdoses. <strong>Don't use alone</strong> so someone can help if you go out.<br><br>Looks = gray<br><br>The Xchange in Greensboro can help provide you with free supplies and advice to stay safe. 'If you want to improve your life we are here to help you. One goal at a time. You make the goals... we listen to you.'<br>1114 Grove Street, Greensboro, NC 27403<br>Phone: 336-669-5543<br>Open: Mon 1-7pm, Tue 1-7pm, Thu 1-5pm, Fri 1-8pm<br>ncurbansurvivorunion.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 7.66 = cocaine</li><li>Peak 8.95 = heroin</li><li>Peak 9.27 = fentanyl</li></ul><br>Method(s): GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimporant. Contact us if you want details.<br><br>Record for Sample NC01052 last updated  1 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/nc01052',
#    'urlSlug': 'p/nc01052',
#    'images': [{'id': '6297788da3024465ca0ed03b',
#      'altText': 'NC01052.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654093965865-3NHWYCSXPI09WE3RRWFU/NC01052.PNG',
#      'originalSize': {'width': 1893, 'height': 437},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': '82604dd6-04c9-411c-bce0-21a2f8546da5',
#      'sku': 'SQ5541815',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-01T14:32:43.819Z',
#    'modifiedOn': '2022-06-03T18:45:38.954Z'},
#   {'id': '629778626145924311fe75a2',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': 'NC01012',
#    'description': "<p>From Greensboro, North Carolina on 7/29/2021<br>Assumed to be heroin<br><br><strong>Pretty sample with only 1 major substance detected:<ul><li>inositol</li></ul></strong><br>Looks = gray rock<br><br>The Xchange in Greensboro can help provide you with free supplies and advice to stay safe. 'If you want to improve your life we are here to help you. One goal at a time. You make the goals... we listen to you.'<br>1114 Grove Street, Greensboro, NC 27403<br>Phone: 336-669-5543<br>Open: Mon 1-7pm, Tue 1-7pm, Thu 1-5pm, Fri 1-8pm<br>ncurbansurvivorunion.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 6.58 = inositol</li></ul><br>Method(s): GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimporant. Contact us if you want details.<br><br>Record for Sample NC01012 last updated  1 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/nc01012',
#    'urlSlug': 'p/nc01012',
#    'images': [{'id': '62977863a3024465ca0ecafb',
#      'altText': 'NC01012.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654093923693-K7E9RDO5JIOAHVY86UC2/NC01012.PNG',
#      'originalSize': {'width': 1891, 'height': 439},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': 'd4a4de3a-8916-48b3-a2ff-5705c1e0e3f6',
#      'sku': 'SQ7563664',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-01T14:32:02.376Z',
#    'modifiedOn': '2022-06-03T18:45:38.954Z'},
#   {'id': '6297783f165fee684efeb9d9',
#    'type': 'PHYSICAL',
#    'storePageId': '6283aa2f96a4e3205eaf774e',
#    'name': 'NC01072',
#    'description': "<p>From Greensboro, North Carolina on 7/13/2021<br>Assumed to be cocaine<br><br><strong>2 major substances detected:<ul><li>p-fluorofentanyl</li><li>xylazine</li></ul></strong><br>But we found lots of contaminants too, with traces of 4-ANPP + despropionyl p-fluorofentanyl + sucrose + cocaine + p-fluoro phenethyl 4-ANPP + fentanyl. Trace substances in small quantities can sometimes be harmless, but other times can cause health problems. If you have unexpected sensations, it may be due to these.<br><br><strong>Fentanyl</strong> is potent and the amount changes by batch. If you weren't expecting it, consider getting test strips online or from a harm reduction program. <strong>Carry naloxone (Narcan)</strong> to reverse overdoses. <strong>Don't use alone</strong> so someone can help if you go out.<br><br><strong>Xylazine</strong> causes serious skin problems. These can happen anywhere on the body and don't heal quickly. And, <strong>xylazine</strong> can come on stronger than traditional dope and knock you out, so <strong>be mindful of your surroundings</strong>. It's best to avoid dope with xylazine. You might need medical attention to prevent long-term damage.<br><br><strong>Fluorofentanyl</strong> is showing up recently. It's the result of different raw materials being used to make fentanyl. We don't know yet if it causes any specific problems.<br><br>Looks = white, gray<br><br>The Xchange in Greensboro can help provide you with free supplies and advice to stay safe. 'If you want to improve your life we are here to help you. One goal at a time. You make the goals... we listen to you.'<br>1114 Grove Street, Greensboro, NC 27403<br>Phone: 336-669-5543<br>Open: Mon 1-7pm, Tue 1-7pm, Thu 1-5pm, Fri 1-8pm<br>ncurbansurvivorunion.org<br><br><strong>Major substances in graph:<br></strong><ul><li>Peak 6.95 = xylazine</li><li>Peak 9.13 = p-fluorofentanyl</li></ul><br>Method(s): GCMS + Derivatized GCMS<br>Peaks that don't appear on the graph were detected using other advanced methods. If a peak appears on the graph but isn't listed above, then we reviewed it and determined it's unimporant. Contact us if you want details.<br><br>Record for Sample NC01072 last updated  1 Jun 2022.",
#    'url': 'https://www.streetsafe.supply/results/p/nc01072',
#    'urlSlug': 'p/nc01072',
#    'images': [{'id': '62977841a3024465ca0ec71f',
#      'altText': 'NC01072.PNG',
#      'orderIndex': 0,
#      'url': 'https://images.squarespace-cdn.com/content/v1/6283a9c2e4d8cc398e6e998b/1654093889998-V2FSE6QNUADMQTK7SH1R/NC01072.PNG',
#      'originalSize': {'width': 1893, 'height': 437},
#      'availableFormats': ['100w', '300w', '500w', '750w', '1000w', '1500w']}],
#    'tags': [],
#    'isVisible': True,
#    'variantAttributes': [],
#    'variants': [{'id': 'ad7e3c29-4296-4b98-9618-6be82c094835',
#      'sku': 'SQ8037163',
#      'pricing': {'basePrice': {'value': '0.00', 'currency': 'USD'},
#       'salePrice': {'value': '0.00', 'currency': 'USD'},
#       'onSale': False},
#      'stock': {'quantity': 0, 'unlimited': True},
#      'attributes': {},
#      'shippingMeasurements': {'weight': {'unit': 'POUND', 'value': 0.0},
#       'dimensions': {'unit': 'INCH',
#        'length': 0.0,
#        'width': 0.0,
#        'height': 0.0}},
#      'image': None}],
#    'seoOptions': None,
#    'createdOn': '2022-06-01T14:31:27.494Z',
#    'modifiedOn': '2022-06-03T18:45:38.954Z'}],
#  'pagination': {'nextPageUrl': 'https://api.squarespace.com/1.0/commerce/products?cursor=eyJzZXJ2aWNlQ3Vyc29yIjoiTlRBIiwibW9kaWZpZWRBZnRlciI6bnVsbCwibW9kaWZpZWRCZWZvcmUiOm51bGwsInF1ZXJ5IjpudWxsfQ',
#   'nextPageCursor': 'eyJzZXJ2aWNlQ3Vyc29yIjoiTlRBIiwibW9kaWZpZWRBZnRlciI6bnVsbCwibW9kaWZpZWRCZWZvcmUiOm51bGwsInF1ZXJ5IjpudWxsfQ',
#   'hasNextPage': True}}
